# %%
import pandas as pd

# Load the JSON file into a DataFrame
file_path = ("company_tickers.json"  
)
df = pd.read_json(file_path)

df = df.T

# Add a new column for processing status
df["processed"] = False

# Save the DataFrame to a CSV file
status_file_path = "processing_status.csv"  
df.to_csv(status_file_path, index=False)

# %%
import pandas as pd 
# read paraquet file
df = pd.read_parquet('ticker_data/MSFT.parquet')

df.head()
# Out:
#       cik ticker           title  year  \
# 0  789019   MSFT  MICROSOFT CORP  2008
# 1  789019   MSFT  MICROSOFT CORP  2021
# 2  789019   MSFT  MICROSOFT CORP  2015
# 3  789019   MSFT  MICROSOFT CORP  2016
# 4  789019   MSFT  MICROSOFT CORP  2010
#
#                                          mda_section  \
# 0  ITEM 7. MANAGEMENT’S DISCUSSION AND ANALYSIS O...
# 1  ITEM 7. MANAGEMENT’S DISCUSSION AND ANALYSIS O...
# 2  ITEM 7. MANAGEMENT’S DISCUSSION AND ANALYSIS O...
# 3  ITEM 7. MANAGEMENT’S DISCUSSION AND ANALYSIS O...
# 4  ITEM 7. MANAGEMENT’S DISCUSSION AND ANALYSIS O...
#
#          processed_timestamp
# 0 2024-01-14 20:33:55.248422
# 1 2024-01-14 20:34:23.960014
# 2 2024-01-14 20:34:24.831113
# 3 2024-01-14 20:34:33.233126
# 4 2024-01-14 20:34:24.348818
