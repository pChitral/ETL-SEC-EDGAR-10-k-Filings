# %%
import os
import json
import re
import pandas as pd
from bs4 import BeautifulSoup
from supabase import create_client
from shutil import rmtree
from dotenv import load_dotenv

from utils.get_ticker_10k_filings import get_ticker_10k_filings
from utils.collect_ticker_files import collect_ticker_files
from utils.new_10k_reports_to_supabase import new_10k_reports_to_supabase
from utils.find_general_section import find_general_section
from utils.delete_txt_files import delete_txt_files
from utils.parse_html_file import parse_html_file

# Supabase API keys
load_dotenv()
SUPABASE_URL = os.environ["SUPABASE_URL"]
SUPABASE_KEY = os.environ["SUPABASE_KEY"]
Client = create_client(SUPABASE_URL, SUPABASE_KEY)


def process_ticker_10k_data(ticker):
    # Download 10-K filings
    get_ticker_10k_filings(ticker)
    ticker_files_dict = collect_ticker_files()

    # Delete .txt files to save space
    delete_txt_files(ticker_files_dict.get(ticker, []))

    # Initialize a dictionary to hold all parsed data
    all_parsed_data = {}

    # Loop through each HTML file to parse and store the data
    for html_file in ticker_files_dict.get(ticker, []):
        if html_file.endswith(".html"):
            path_parts = html_file.split("/")
            cik_year_acc = path_parts[4].split("-")

            if len(cik_year_acc) < 3:
                print(f"Skipping file with unexpected format: {html_file}")
                continue

            CIK, Year, AccessionNumber = cik_year_acc

            try:
                parsed_data = parse_html_file(html_file)
            except Exception as e:
                print(f"Could not parse {html_file} due to error: {e}")
                continue

            try:
                filing_dict = {
                    "ticker": ticker,
                    "cik": CIK,
                    "year": int(Year),
                    "accession_number": AccessionNumber,
                    "parsed_data": json.dumps(parsed_data),
                }
            except ValueError:
                print(f"Skipping file with invalid year format in {html_file}")
                continue

            all_parsed_data[AccessionNumber] = filing_dict

    # Create a list of all parsed data dictionaries
    all_parsed_data_list = list(all_parsed_data.values())

    # Insert parsed data into Supabase
    new_10k_reports_to_supabase(all_parsed_data_list, Client)

    # Clear the data folder after processing
    rmtree("data")

    return all_parsed_data


# Example usage
# Replace with your loop over tickers
all_tickers_data = {}
tickers = ["AAPL", "GOOG"]  # Add your list of tickers here

for ticker in tickers:
    all_tickers_data[ticker] = process_ticker_10k_data(ticker)
# Out:
# 2023-09-12 15:12:57,401:INFO - Initializing default bucket(InMemoryBucket) with rates: [limit=10/1000]
# 2023-09-12 15:12:57,401:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:12:59,407:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 4 items
# 2023-09-12 15:13:01,412:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 8 items
# 2023-09-12 15:13:03,418:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 8 items
# 2023-09-12 15:13:05,423:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 9 items
# 2023-09-12 15:13:07,425:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 10 items
# 2023-09-12 15:13:09,430:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 11 items
# Collecting Tickers: 100%|██████████| 1/1 [00:00<00:00, 893.74ticker/s]
# Files are ready for AAPL
# /Users/chitralpatil/Documents/Research/ETL-10-k-Filings/venv/lib/python3.11/site-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# 2023-09-12 15:13:11,442:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 7 items
# 2023-09-12 15:13:13,558:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:13:15,657:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15
INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:23:21,138:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:23:23,143:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:23:25,149:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:23:27,152:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:23:29,154:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:23:31,160:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:23:33,165:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:23:35,171:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:23:37,176:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:23:39,179:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:23:41,184:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:23:43,187:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:23:45,193:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:23:47,194:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:23:49,199:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# ...
# 2023-09-12 15:38:43,194:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:38:45,200:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:38:47,204:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:38:49,208:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:38:51,213:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:38:53,219:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:38:55,222:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:38:57,228:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:38:59,232:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:01,234:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:03,239:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:05,245:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:07,250:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:09,255:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:11,257:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:13,262:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:15,267:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:17,270:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:19,275:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:21,277:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:23,283:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:25,288:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:27,294:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:29,299:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:31,305:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:33,308:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:35,313:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:37,318:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:39,323:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:41,328:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:43,334:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:45,340:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:47,345:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:49,351:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:51,356:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:53,362:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:55,367:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:57,373:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:39:59,377:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:01,382:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:03,388:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:05,393:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:07,395:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:09,401:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:11,403:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:13,408:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:15,414:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:17,419:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:19,425:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:21,430:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:23,436:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:25,442:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:27,446:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:29,451:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:31,457:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:33,462:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:35,468:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:37,470:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:39,475:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:41,481:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:43,486:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:45,488:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:47,494:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:49,499:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:51,505:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:53,510:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:55,516:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:57,522:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:40:59,525:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:01,531:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:03,537:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:05,542:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:07,545:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:09,550:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:11,556:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:13,562:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:15,567:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:17,573:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:19,578:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:21,584:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:23,590:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:25,595:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:27,601:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:29,606:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:31,612:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:33,617:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:35,623:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:37,628:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:39,630:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:41,635:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:43,640:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:45,646:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:47,651:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:49,657:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:51,663:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:53,665:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:55,670:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:57,673:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:41:59,678:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:42:01,682:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:42:03,687:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:42:05,693:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:42:07,698:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:42:09,702:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:42:11,707:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:42:13,709:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:42:15,712:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:42:17,712:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:42:19,718:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:42:21,724:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:42:23,729:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:42:25,735:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items
# 2023-09-12 15:42:27,741:INFO - (sync)leaking bucket: <pyrate_limiter.buckets.in_memory_bucket.InMemoryBucket object at 0x12647e850>, 0 items

# %%
import pandas as pd 
df = pd.read_json('company_tickers.json', orient='index')
all_tickers_data = {}
tickers = df['ticker'].tolist()

for ticker in tickers:
    all_tickers_data[ticker] = process_ticker_10k_data(ticker)
# Out:
# 10909

# %%
import pandas as pd 
df = pd.read_json('company_tickers.json', orient='index')
print(len(df))
# Out:
# 10909

# %%
df.head()
# Out:
#    cik_str ticker           title
# 0   320193   AAPL      Apple Inc.
# 1   789019   MSFT  MICROSOFT CORP
# 2  1652044  GOOGL   Alphabet Inc.
# 3  1018724   AMZN  AMAZON COM INC
# 4  1045810   NVDA     NVIDIA CORP

# %%
df['cik_str'].nunique()
# Out:
# 8350
